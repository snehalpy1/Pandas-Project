# %%
import pandas as pd

# %% [markdown]
# Q1. What data structure(s) could you store this data in? What are the benefits of storing in each of the data structures you can think of?
# -> We are using csv file to store this data and using  pandas we can read this csv

# %%
df= pd.read_csv("Programming Exercise Data_World Population Data.csv")

# %%
df
# Out:
#      Country Name      1960      1961      1962      1963      1964      1965  \
# 0           Aruba     54208     55434     56234     56699     57029     57357
# 1     Afghanistan   8996967   9169406   9351442   9543200   9744772   9956318
# 2          Angola   5454938   5531451   5608499   5679409   5734995   5770573
# 3         Albania   1608800   1659800   1711319   1762621   1814135   1864791
# 4         Andorra     13410     14378     15379     16407     17466     18542
# ..            ...       ...       ...       ...       ...       ...       ...
# 209        Kosovo    947000    966000    994000   1022000   1050000   1078000
# 210   Yemen, Rep.   5315351   5393034   5473671   5556767   5641598   5727745
# 211  South Africa  17099836  17524533  17965733  18423157  18896303  19384838
# 212        Zambia   3070780   3164330   3260645   3360099   3463211   3570466
# 213      Zimbabwe   3776679   3905038   4039209   4178726   4322854   4471178
#
# ...

# %% [markdown]
# Q2. Write a program/function to find the country/region with the highest and lowest population in a given year. Take the year as input from the user or from the command line.

# %%
def get_high_low_pop(year,df):
    high_pop= df["1960"].max()
    low_pop = df["1960"].min()
    high_pop_region = df["Country Name"].loc[df["1960"]==high_pop].values[0]  
    low_pop_region = df["Country Name"].loc[df["1960"]==low_pop].values[0]
    return high_pop_region,low_pop_region
    
high_poget_high_low_pop

# %%
high_pop
# Out:
# 2126448264

# %%
high_pop_region.values[0]
# Out:
# 'Middle income'

# %%
low_pop_region
# Out:
# 182    Sint Maarten (Dutch part)
# Name: Country Name, dtype: object

# %%
df.iloc[126]
# Out:
# Country Name    Middle income
# 1960               2126448264
# 1961               2152809007
# 1962               2192361842
# 1963               2243997513
#                     ...
# 2016             5610235989.0
# 2017             5674542216.0
# 2018             5736478191.0
# 2019             5796189831.0
# 2020             5853079114.0
# Name: 126, Length: 62, dtype: object
